# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------------------------------------------
# 1. データの準備
# -------------------------------------------------------------------

# (1) 折れ線グラフ用データ
y0 = [1, 2, -5, 2]
axes[0,0].plot(y0)

# (2) sin関数用データ
x = np.linspace(0, 10, 100)
y = 2 + 2 * np.sin(2 * x)

# (3) ヒストグラム用データ (正規分布に従う乱数)
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 60)
y = 4 + np.random.normal(0, 2, len(x))

# (4) 散布図用データ
x_scatter = np.random.rand(50) * 10
y_scatter = 2 * x_scatter + np.random.randn(50) * 5

# -------------------------------------------------------------------
# 2. 複数のグラフを1つのキャンバスに配置
# -------------------------------------------------------------------

# 描画キャンバス (Figure) と4つのサブプロット領域 (Axes) を作成
# グラフが重ならないようにレイアウトを調整
fig, axes = plt.subplots(nrows=2, ncols=2)
plt.tight_layout()

# 1. 折れ線グラフ (左上: axes[0, 0])
axes[0, 0].plot(x_line, y_line, marker='o', linestyle='-', color='blue')

# 2. sin関数 (右上: axes[0, 1])
axes[0, 1].plot(x_sin, y_sin, color='red')

# 3. ヒストグラム (左下: axes[1, 0])
axes[1, 0].hist(data_hist, bins=30, color='green', alpha=0.7)

# 4. 散布図 (右下: axes[1, 1])
axes[1, 1].scatter(x_scatter, y_scatter, color='purple', alpha=0.6, s=50)

# グラフの表示
plt.show()
